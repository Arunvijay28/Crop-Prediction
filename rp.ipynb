# %%
import matplotlib.pyplot as plt

x=['Rice','Millet','Coffee','groundnut']
y=[13,10,8,4]

plt.bar(x,y)
plt.xlabel('Crops')
plt.ylabel('Rank')
plt.show()

# %%
x=['Organic(grade A)','Chemical (grade B)']
y=[4,2]
plt.bar(x,y)
plt.xlabel('Fertilizer')
plt.ylabel('Rank')
plt.show()
